# %%
import sys
sys.path.append("../")

# %%
from dsbtorch import scan_dataset, IterableVideoSlidingWindowDataset

# %%
sd = scan_dataset('/home/ubuntu/data/videos/', 2)
# Out:
# 100%|██████████| 36250/36250 [28:39<00:00, 21.08it/s]

# %%
d = IterableVideoSlidingWindowDataset(sd)

# %%
it = iter(d)

# %%
a = next(it)
b = next(it)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)
fig.suptitle('Sliding Window Frame Comparison')
ax1.imshow(a['frames'][0])
ax1.set_title("Window 0, Frame 0")
ax2.imshow(a['frames'][1])
ax2.set_title("Window 0, Frame 1")
ax3.imshow(b['frames'][0])
ax3.set_title("Window 1, Frame 0")
ax4.imshow(b['frames'][1])
ax4.set_title("Window 1, Frame 1")

fig.show()

# %%
# Window 0 Frame 1 and Window 1 frame 0 do look equal, but confirm:
a_second = a['frames'][1]
b_first = b['frames'][0]
np.all(a_second == b_first)
# Out:
# True
